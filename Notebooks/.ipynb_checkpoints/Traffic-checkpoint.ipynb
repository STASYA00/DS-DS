# %%
import pandas as pd
import matplotlib.pyplot as plt
# import geopandas as gpd
import numpy as np
import os
import scipy as sc
import requests
import datetime

# %%
file = pd.read_csv('../traffic/Traffic_dataset_v0.1.csv', parse_dates=['DATETIME'], date_parser=lambda x: pd.to_datetime(x, format='%Y-%m-%d %H:%M'))
file.head()
# Out:
#    ID_SENSOR DIRECTION            DATETIME  NUM_VEHICLES  SPEED_MEAN  \
# 0          1         A 2018-09-01 02:00:00           NaN         NaN
# 1          1         A 2018-09-01 02:15:00           NaN         NaN
# 2          1         A 2018-09-01 02:30:00           NaN         NaN
# 3          1         A 2018-09-01 02:45:00           NaN         NaN
# 4          1         A 2018-09-01 03:00:00           NaN         NaN
#
#    SPEED_SD     EVENT        LON        LAT
# 0       NaN  NO_EVENT  12.291754  41.800588
# 1       NaN  NO_EVENT  12.291754  41.800588
# 2       NaN  NO_EVENT  12.291754  41.800588
# 3       NaN  NO_EVENT  12.291754  41.800588
# 4       NaN  NO_EVENT  12.291754  41.800588

# %%
file.DATETIME[0].timestamp()
# Out:
# 1535767200.0

# %%
file_new = file.dropna(subset=['NUM_VEHICLES', 'SPEED_MEAN', 'SPEED_SD'], axis=0, thresh=2)
file_new = file_new.reset_index()

# %%
weather = []

# %%
for i in range (0,1000):
    a = requests.get('https://api.darksky.net/forecast/0ee33782e549c1b338635079fea0b22d/' + str(file_new.LAT[i]) + ',' + str(file_new.LON[i]) + ',' + str(file_new.DATETIME[i].timestamp())[:10] + '?units=si&exclude=daily,flags,offset,hourly')
    weather.append(a)
    
len(weather)
# Out:
# 1000

# %%
weather
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>,
#  <Response [403]>]

# %%
weather[0].json()['currently']
# Out:
# {'time': 1535788800,
#  'summary': 'Partly Cloudy',
#  'icon': 'partly-cloudy-day',
#  'precipType': 'rain',
#  'temperature': 24.69,
#  'apparentTemperature': 25.02,
#  'dewPoint': 18.63,
#  'humidity': 0.69,
#  'pressure': 1014.98,
#  'pressureError': 14.31,
#  'windSpeed': 5.04,
#  'windBearing': 173,
#  'cloudCover': 0.56,
#  'uvIndex': 3,
#  'visibility': 10.01}

# %%
temp = []
vis = []
hum = []
wind = []
prec = []
pressure = []

# %%
weather[991].json()['currently']['temperature']
# Out:
# 22.48

# %%
weather[1].json()['currently']['visibility']
# Out:
# 10.01

# %%
for x in range (0, 991):
    temp.append(weather[x].json()['currently']['temperature'])
#     vis.append(weather[x].json()['currently']['visibility'])
    hum.append(weather[x].json()['currently']['humidity'])
    wind.append(weather[x].json()['currently']['windSpeed'])
    prec.append(weather[x].json()['currently']['precipType'])
    pressure.append(weather[x].json()['currently']['pressure'])

# %%
len(hum)
# Out:
# 991

# %%
df = pd.DataFrame({'Temp' : temp, 'Humidity' : hum, 'Wind' : wind, 'Precipitation' : prec, 'Pressure' : pressure})
df.head()
# Out:
#     Temp  Humidity  Wind Precipitation  Pressure
# 0  24.69      0.69  5.04          rain   1014.98
# 1  24.78      0.69  5.02          rain   1015.01
# 2  24.86      0.69  5.07          rain   1015.03
# 3  24.95      0.69  5.18          rain   1015.06
# 4  25.03      0.69  5.35          rain   1015.09

# %%
df.to_csv('../traffic/temperature.csv')

# %%
a.json()
# Out:
# {'latitude': 41.800588,
#  'longitude': 12.291754,
#  'timezone': 'Europe/Rome',
#  'currently': {'time': 1535767200,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipType': 'rain',
#   'temperature': 21.24,
#   'apparentTemperature': 21.81,
#   'dewPoint': 19.79,
#   'humidity': 0.91,
#   'pressure': 1014.67,
#   'pressureError': 14.23,
#   'windSpeed': 3.08,
#   'windBearing': 86,
#   'cloudCover': 0.53,
#   'uvIndex': 0,
#   'visibility': 8.51},
#  'offset': 2}
